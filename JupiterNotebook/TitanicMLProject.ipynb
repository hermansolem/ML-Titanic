# %%
import pandas as pd
import numpy as np
data = pd.read_csv('titanic3.csv')

# %%
data.replace('?', np.nan, inplace= True)
data = data.astype({"age": np.float64, "fare": np.float64})

# %%
import seaborn as sns
import matplotlib.pyplot as plt

fig, axs = plt.subplots(ncols=5, figsize=(30,5))
sns.violinplot(x="survived", y="age", hue="sex", data=data, ax=axs[0])
sns.pointplot(x="sibsp", y="survived", hue="sex", data=data, ax=axs[1])
sns.pointplot(x="parch", y="survived", hue="sex", data=data, ax=axs[2])
sns.pointplot(x="pclass", y="survived", hue="sex", data=data, ax=axs[3])
sns.violinplot(x="survived", y="fare", hue="sex", data=data, ax=axs[4])

# %%
data.replace({'male': 1, 'female': 0}, inplace=True)

# %%
data.corr().abs()[["survived"]]
# Out:
#           survived
# pclass    0.312469
# survived  1.000000
# sex       0.528693
# age       0.055512
# sibsp     0.027825
# parch     0.082660
# fare      0.244265
# body           NaN

# %%
#sns.set(rc={'axes.facecolor':'white', 'figure.facecolor':'white'})
sns.set(rc={'axes.facecolor':'black', 'figure.facecolor':'white'})
sns.heatmap(data.corr().abs()[["survived"]]) #heatmap for one variable

# %%
#Checking if having a relative gives higher correlation to survavability than having either parents
#or siblings or spouse

data['relatives'] = data.apply(lambda row: int((row['sibsp'] + row ['parch']) > 0), axis=1)
data.corr().abs()[["survived"]]
# Out:
#            survived
# pclass     0.312469
# survived   1.000000
# sex        0.528693
# age        0.055512
# sibsp      0.027825
# parch      0.082660
# fare       0.244265
# body            NaN
# relatives  0.201719

# %%
#Choose which coloumns to include and drop the NaN rows
data = data[['sex', 'pclass','age','relatives','fare','survived']].dropna()

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(data[['sex','pclass','age','relatives','fare']], 
    data.survived, test_size=0.2, random_state=0)

# %%
#Normalizing features
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
X_train = sc.fit_transform(x_train)
X_test = sc.transform(x_test)

# %%
from sklearn.naive_bayes import GaussianNB
model = GaussianNB()
model.fit(X_train, y_train)
# Out:
# GaussianNB()

# %%
from sklearn import metrics
predict_test = model.predict(X_test)
print("The trained algorithm had a success rate of: " + str(round(metrics.accuracy_score(y_test, predict_test)*100)) + " %")
# Out:
# The trained algorithm had a success rate of: 75.0 %
